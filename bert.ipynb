# %%
import tensorflow as tf
import matplotlib.pyplot as plt
tf.__version__

# %%
# !pip install -q tf-models-official==2.7.0 #  HAS TO BE THE SAME VERSION AS TENSORFLOW

# %%
# !pip install tensorflow_addons
# !pip install ml_collections
#? !pip install tensorflow-text
# !pip install -q tf-models-official

# %%
import importlib
import experiments.config as conf
importlib.reload(conf)


config = conf.multilabel_base()
# config.bert.bert_version = 'small_bert/bert_en_uncased_L-12_H-768_A-12'
config.bert.bert_version = 'bert_en_cased_L-12_H-768_A-12'
config.lr=1e-4
# config.bert.bert_version = 'small_bert/bert_en_uncased_L-6_H-256_A-4'

# %%
from data_processing.ev_parser import create_dataset

train_ds = create_dataset(batch_size=config.batch_size)
val_ds = create_dataset(batch_size=config.batch_size, is_training=False, split='valid')
test_ds = create_dataset(batch_size=config.batch_size, is_training=False, split='test')

# %%
import tensorflow_text as text  # Registers the ops.
import model.classifier as mc 
importlib.reload(mc)

cls = mc.MultiLabelClassifier(config.bert)

# %%
cls.compile(train_ds, epochs=20)

# %%
cls.train(train_ds, val_ds, '.')
# Out:
# Epoch 1/20
# 1066/1066 [==============================] - 584s 528ms/step - loss: 0.3125 - binary_accuracy: 0.8682 - f1_score: 0.4905 - val_loss: 0.2168 - val_binary_accuracy: 0.9062 - val_f1_score: 0.6719

# %%
cls.model.evaluate(test_ds)
# Out:
# 134/134 [==============================] - 6s 47ms/step - loss: 0.3592 - binary_accuracy: 0.9087 - f1_score: 0.7169
# [0.3592170178890228,
#  0.9086538553237915,
#  array([0.8462239 , 0.5945946 , 0.7772727 , 0.8133971 , 0.5089606 ,
#         0.73827535, 0.80203044, 0.65441173], dtype=float32)]
